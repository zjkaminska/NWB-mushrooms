# %%
! pip install scikit-learn 
! pip install matplotlib 
! pip install pandas
! pip install numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
observations_df = pd.read_csv('mushroom_observations.csv')
characteristics_df = pd.read_csv('mushroom_characteristics.csv', delimiter = ";")
len(m_characteristics_df)
# Out:
# 173

# %%
observations_df = observations_df['class;cap-diameter;cap-shape;cap-surface;cap-color;does-bruise-or-bleed;gill-attachment;gill-spacing;gill-color;stem-height;stem-width;stem-root;stem-surface;stem-color;veil-type;veil-color;has-ring;ring-type;spore-print-color;habitat;season'].str.split(';', expand=True)
observations_df.columns = ['class', 'cap-diameter', 'cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', 'gill-spacing', 'gill-color', 'stem-height', 'stem-width', 'stem-root', 'stem-surface', 'stem-color', 'veil-type', 'veil-color', 'has-ring', 'ring-type', 'spore-print-color', 'habitat', 'season']
merged_df = pd.concat([characteristics_df, observations_df], ignore_index=True)
display(merged_df.head())
# Out:
#            family               name class cap-diameter cap-shape Cap-surface  \
# 0  Amanita Family         Fly Agaric     p     [10, 20]    [x, f]      [g, h]
# 1  Amanita Family        Panther Cap     p      [5, 10]    [p, x]         [g]
# 2  Amanita Family  False Panther Cap     p     [10, 15]    [x, f]         NaN
# 3  Amanita Family        The Blusher     e      [5, 15]    [x, f]         NaN
# 4  Amanita Family          Death Cap     p      [5, 12]    [x, f]         [h]
#
#   cap-color does-bruise-or-bleed gill-attachment gill-spacing  ... stem-color  \
# 0    [e, o]                  [f]             [e]          NaN  ...        [w]
# 1       [n]                  [f]             [e]          NaN  ...        [w]
# 2    [g, n]                  [f]             [e]          NaN  ...        [w]
# 3       [n]                  [t]             NaN          NaN  ...        [w]
# 4       [r]                  [f]             NaN          [c]  ...        [w]
#
# ...
